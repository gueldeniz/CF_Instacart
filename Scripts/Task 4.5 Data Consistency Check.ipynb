# %% [markdown]
# # Data Consistency Check

# %%
#Importing libraries

import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\Güldeniz\Desktop\Career Foundry\2. Data Immersion\Achievement 4\Instacart  Basket Analysis'

# %%
#products data frame
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %%
#orders data frame
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = False)

# %%
df_ords.describe()
# Out:
#            order_id       user_id  order_number     order_dow  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01  5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# 75%         1.600000e+01            1.500000e+01
# ...

# %% [markdown]
# ### Mixed-Type Data

# %%
# Create a datafrane
df_test = pd.DataFrame()

# %%
#Create a mixed type column
df_test['mix'] = ['a', 'b', 1, True]

# %%
df_test.head()
# Out:
#     mix
# 0     a
# 1     b
# 2     1
# 3  True

# %%
#Check for mixed types (always check for mixed-type columsn before moving forward)
for col in df_test.columns.tolist():
    weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply (type)).any(axis = 1)
    if len (df_test[weird])>0:
        print (col)
# Out:
# mix

# %%
#Changing from numeric to string
df_test['mix']= df_test ['mix'].astype('str')

# %% [markdown]
# ### Missing Values

# %%
#Finding missing values
df_prods.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
#To actually view these 16 values, you can create a subset of the dataframe containing only the values in question
df_nan = df_prods[df_prods['product_name'].isnull()== True]

# %%
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# ...

# %%
# Compare the number of rows in your current dataframe with the number in your subset once the missing rows have been removed:

df_prods.shape
# Out:
# (49693, 5)

# %%
#Subset without the missing values
df_prods_clean = df_prods[df_prods['product_name'].isnull()== False]

# %%
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
# Dropping the  missing values: df_prods.dropna(inplace=True)
# Drop only the NaNs from a particular column: df_prods.dropna(subset = ['product_name'], inplace = True])
# inplace = True overwrites the original dataset (risky), inplace=False will only return a 'view' of the changed 
# ...dataframe, original dataframe left untouched.

# %% [markdown]
# ### Duplicates

# %%
df_prods.head(10)
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
# 5           6                                       Dry Nose Oil        11
# 6           7                     Pure Coconut Water With Orange        98
# 7           8                  Cut Russet Potatoes Steam N' Mash       116
# 8           9                  Light Strawberry Blueberry Yogurt       120
# 9          10     Sparkling Orange Juice & Prickly Pear Beverage       115
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# ...

# %%
# The duplicated() function is what identifies duplicate rows.
df_dups = df_prods_clean [df_prods_clean.duplicated()]

# %%
df_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %%
# Addressing the duplicates: df.drop_duplicates()
#check the current number of rows in df_prods_clean dataframe by shape function.
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
#Creating a dataframe that does not include the duplicates
df_prods_clean_no_dups = df_prods_clean.drop_duplicates()

# %%
df_prods_clean_no_dups.shape  # 5 duplicate values are dropped.
# Out:
# (49672, 5)

# %% [markdown]
# ### Tidying Up and Exporting Changes

# %%
df_prods_cleaned = df_prods_clean_no_dups

# %%
#exporting cleaned products.csv dataframe
df_prods_cleaned.to_csv(os.path.join(path,'02 Data','Prepared Data','products_cleaned.csv'), index=False)

# %% [markdown]
# # Task 4.5 Data Consistency Check

# %% [markdown]
# ### 2. Run df.describe function on your df_prods dataframe

# %%
df_prods.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49693.000000  49693.000000   49693.000000  49693.000000
# mean   24844.345139     67.770249      11.728433      9.994136
# std    14343.717401     38.316774       5.850282    453.519686
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12423.000000     35.000000       7.000000      4.100000
# 50%    24845.000000     69.000000      13.000000      7.100000
# 75%    37265.000000    100.000000      17.000000     11.200000
# max    49688.000000    134.000000      21.000000  99999.000000

# %%
df_prods_cleaned.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49672.000000  49672.000000   49672.000000  49672.000000
# mean   24850.349775     67.762442      11.728942      9.993282
# std    14340.705287     38.315784       5.850779    453.615536
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12432.750000     35.000000       7.000000      4.100000
# 50%    24850.500000     69.000000      13.000000      7.100000
# 75%    37268.250000    100.000000      17.000000     11.100000
# max    49688.000000    134.000000      21.000000  99999.000000

# %% [markdown]
# ##### => Cheking the count, the dropped values show themselves. There is no change, however, in min and max values. Dataframe looks OK!

# %% [markdown]
# ### 3. Check for mixed-type data in df_ords dataframe.

# %%
df_ords.head(50)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# 5    3367565        1    prior             6          2                  7
# 6     550135        1    prior             7          1                  9
# 7    3108588        1    prior             8          1                 14
# 8    2295261        1    prior             9          1                 16
# 9    2550362        1    prior            10          4                  8
# 10   1187899        1    train            11          4                  8
# ...

# %%
df_ords.tail(50)
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 3421033   1949208   206208    prior            15          2
# 3421034   3049681   206208    prior            16          2
# 3421035     11859   206208    prior            17          1
# 3421036    447879   206208    prior            18          3
# 3421037   2467456   206208    prior            19          4
# 3421038    842771   206208    prior            20          0
# 3421039   2471606   206208    prior            21          5
# 3421040   2922221   206208    prior            22          1
# 3421041   3128968   206208    prior            23          5
# 3421042   2573371   206208    prior            24          5
# 3421043   2804556   206208    prior            25          2
# 3421044   2079142   206208    prior            26          2
# 3421045    183408   206208    prior            27          2
# 3421046   3038194   206208    prior            28          0
# ...

# %% [markdown]
# ### 4. If you find mixed-type data, fix it.
# ##### => Checking the df-ords dataframe, I could not see any mixed-type data.

# %% [markdown]
# ### 5.Run a check for missing values in your df_ords dataframe

# %%
#Finding missing values
df_ords.isnull().sum()
# Out:
# order_id                       0
# user_id                        0
# eval_set                       0
# order_number                   0
# order_dow                      0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %% [markdown]
# #####  => The only column with missing values is days_since_prior_order. There are 206209 missing values in this column, which is a lot! The reason for this many mssing values can be the fact that, many of the orders can be the first orderof the user. That means, there is no value to give for numbers of days since the prior order.

# %% [markdown]
# ### 6. Address the missing values using an appropiate method.
# ##### => For the missing values in 'days_since_prior_order' I would chose to impute the missing values (NaN) with value 0. Since these missing values should represent new customers, without prior orders.

# %%
#checking the shape of the dataframe

df_ords.shape
# Out:
# (3421083, 7)

# %%
#Imputation with a 0 value:

df_ords['days_since_prior_order']=df_ords['days_since_prior_order'].fillna(0)

# %%
#Controlling the imputation

df_ords.isnull().sum()
# Out:
# order_id                  0
# user_id                   0
# eval_set                  0
# order_number              0
# order_dow                 0
# order_hour_of_day         0
# days_since_prior_order    0
# dtype: int64

# %% [markdown]
# ### 7. Run a check for duplicate values in your df_ords data

# %%
df_ords_dups = df_ords[df_ords.duplicated()]

# %%
df_ords_dups
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, eval_set, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []

# %% [markdown]
# ##### => there are no duplicate values in orders dataframe.

# %% [markdown]
# ### 8. Address the duplicates using an appropriate method
# ##### => There are no duplicate values.
# ##### => If there were any duplicate values, I would  use the function: df_ords_no_dups = df_ords.drop_duplicates().  I would also check the row and column numbers before and after I run the dropping duplicates function.

# %% [markdown]
# ### 9. Export your final cleaned df_prods and df_ords data as "".csv" files.

# %%
#Exporting df_ords dataframe:

df_ords_cleaned = df_ords
df_ords_cleaned.to_csv(os.path.join(path,'02 Data','Prepared Data','orders_cleaned.csv'), index=False)

# %% [markdown]
# ##### => 'products_clean.csv' file was exported in earlier stages (see. Tidying up and exporting changes)
